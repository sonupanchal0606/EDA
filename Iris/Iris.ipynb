# %% [markdown]
# # Importing modules and libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading Data

# %%
#load iris data set
iris = pd.read_csv("iris.csv")

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 7      8            5.0           3.4            1.5           0.2
# 20    21            5.4           3.4            1.7           0.2
# 122  123            7.7           2.8            6.7           2.0
# 2      3            4.7           3.2            1.3           0.2
# 103  104            6.3           2.9            5.6           1.8
#
#             Species
# 7       Iris-setosa
# 20      Iris-setosa
# 122  Iris-virginica
# 2       Iris-setosa
# 103  Iris-virginica

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# how many points for each data class are present?
# or How many followers for each species are present?
iris["Species"].value_counts()
# Balanced data set versus imbalanced data set
# Iris is balanced data set as the number of data points for each class is same
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# No duplicates and Null Values in the Dataset

# %%
iris.duplicated().sum()
# Out:
# 0

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.isnull().sum().sum()
# Out:
# 0

# %%
iris[iris.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ## Species Frequency

# %%
sns.countplot(data=iris,x='Species',hue='Species',palette='hsv')
plt.ylabel('Frequency')
plt.title('Species Frequency')
plt.legend()
plt.show()

# %%
iris['Species'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %%
iris['Species'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 2D scatter Plot
# ### Sepal Length Vs Sepal Width

# %%
iris.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
plt.show()

# %%
# cannot make sense out of it
# What if we colour the points by their class-labels/flower-type?

# %%
sns.scatterplot(data=iris,x='SepalLengthCm',y='SepalWidthCm',hue='Species',palette='Set1')
plt.title('Sepal Length Vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length Vs Sepal Width')

# %%
# can we draw multiple 2D scatter plots for each combination of features?
# How many such combinations exist ? ----> 4C2

# %% [markdown]
# ## Petal Width Distribution

# %%
sns.histplot(iris['PetalWidthCm'],kde=True)
plt.ylabel('Occurrence')
plt.title('PetalWidthCm Distribution')
# Out:
# Text(0.5, 1.0, 'PetalWidthCm Distribution')

# %%
plt.hist(iris['PetalWidthCm'])
plt.xlabel('Petal Width')
plt.ylabel('Number of observations')
plt.title('PetalWidthCm Distribution')
plt.show()

# %%
# in Histogram we can play with the size of the bins, let's try to see how it would change our graph
plt.hist(iris['PetalWidthCm'], bins=20)
plt.xlabel('Petal Width')
plt.ylabel('Number of observations')
plt.show()

# with twice as many bins we can see that the distribution of the variable is rather spread out giving us a rather realistic look over the data.

# %%
bins=[0,0.5,1,1.5,2,2.5]
val=pd.cut(iris['PetalWidthCm'],bins=bins).value_counts()
sns.barplot(x=val.index,y=val,palette='gist_rainbow')
plt.ylabel('Frequency')
plt.title('Petal Width Frequency')
for i,j in enumerate(val.sort_index()):
    plt.text(i,j,j,va='bottom')

# %%
#sns.distplot(iris['PetalWidthCm'],kde=True, bins = 30, hue='Species')

sns.displot(data=iris,x='PetalWidthCm',hue='Species',fill=True,kde=True, palette='Set1')
#sns.displot(data=iris,x='PetalWidthCm',hue='Species', kind='kde',fill=True, palette='Set1')
plt.ylabel('Occurrence')
plt.title('PetalWidthCm Distribution')
plt.show()

# PDF = Smooth Histogram (KDE)
# Out:
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# ## Heatmap For Correlation

# %%
sns.heatmap(data=iris.drop(['Species','Id'],axis=1).corr(),annot=True,cmap='copper')
# Out:
# <Axes: >

# %% [markdown]
# ###### Only Sepal Width is negatively correlated
# ###### Other Features are strongly correlated with each other

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(iris, hue='Species') #sns.pairplot(data=iris)

# With the help of pair plot we can visualize >= 4D graphs 
# The plots opposite to diagonals are symmetric to each others.
# Possible pair plots are nC2
# Out:
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 3D scatter Plot

# %% [markdown]
# https://plotly.com/python/3d-scatter-plots/

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()
# Out:
# <div>                            <div id="617dcafc-42dc-4e09-b122-347bc92b6239" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("617dcafc-42dc-4e09-b122-347bc92b6239")) {                    Plotly.newPlot(                        "617dcafc-42dc-4e09-b122-347bc92b6239",                        [{"hovertemplate":"species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<br>petal_width=%{z}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","scene":"scene","showlegend":true,"x":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"y":[3.5,3.0,3
# ...

# %% [markdown]
# # Histogram, PDF, CDF

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_setosa=iris.loc[iris["Species"]=="Iris-setosa"];
#iris_setosa
iris_versicolor=iris.loc[iris["Species"]=="Iris-versicolor"];
iris_virginica=iris.loc[iris["Species"]=="Iris-virginica"];

# %%
plt.plot(iris_setosa["PetalLengthCm"],np.zeros_like(iris_setosa['PetalLengthCm']), 'o')
plt.plot(iris_versicolor["PetalLengthCm"],np.zeros_like(iris_versicolor['PetalLengthCm']), 'o')
plt.plot(iris_virginica["PetalLengthCm"],np.zeros_like(iris_virginica['PetalLengthCm']), 'o') 
plt.show()

# %%
sns.distplot(iris[iris['Species']== 'Iris-setosa']['PetalLengthCm'])
# Out:
# /var/folders/3t/znjycnnx779_g3tgzpj3n7gm0000gn/T/ipykernel_26111/2926029116.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.FacetGrid(iris, hue="Species") \
   .map(sns.distplot, "PetalLengthCm") \
   .add_legend();
plt.show();
# Out:
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
sns.FacetGrid(iris, hue="Species") \
   .map(sns.distplot, "PetalWidthCm") \
   .add_legend();
plt.show();
# Out:
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
sns.FacetGrid(iris, hue="Species") \
   .map(sns.distplot, "SepalLengthCm") \
   .add_legend();
plt.show();
# Out:
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
sns.FacetGrid(iris, hue="Species") \
   .map(sns.distplot, "SepalWidthCm") \
   .add_legend();
plt.show();
# Out:
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /Users/sonupanchal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %% [markdown]
# ## Calculating PDF Points

# %%
counts, bin_edges = np.histogram(iris_setosa['PetalLengthCm'], bins=10, 
                                 density = False)

print("Prrinting the counts for histogram\n",counts)
pdf = counts/(sum(counts))
print("Sum of count is\n",sum(counts))
print("Printing Edges of bins \n",bin_edges)
print("PDF is as followes  \n",pdf);

plt.gca().legend(('Pdf'))
plt.title('PDF and PDF For iris_setosa')
plt.xlabel("Petal length")
plt.ylabel("Percentage")
plt.plot(bin_edges[1:],pdf)
# Out:
# Prrinting the counts for histogram
#  [ 1  1  2  7 12 14  7  4  0  2]
# Sum of count is
#  50
# Printing Edges of bins
#  [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# PDF is as followes
#  [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]

# %% [markdown]
# ## Calculating CDF Points

# %%
counts, bin_edges = np.histogram(iris_setosa['PetalLengthCm'], bins=10, 
                                 density = False)

print("Prrinting the counts for histogram\n",counts)
pdf = counts/(sum(counts))
print("Sum of count is\n",sum(counts))

print("Printing Edges of bins \n",bin_edges)

print("PDF is as followes  \n",pdf);

cdf = np.cumsum(pdf)
print("CDF Is as followes\n",cdf)
plt.gca().legend(('Cdf'))
plt.title('CDF For iris_setosa')
plt.xlabel("Petal length")
plt.ylabel("Percentage")

plt.plot(bin_edges[1:],cdf)
# Out:
# Prrinting the counts for histogram
#  [ 1  1  2  7 12 14  7  4  0  2]
# Sum of count is
#  50
# Printing Edges of bins
#  [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# PDF is as followes
#  [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# CDF Is as followes
#  [0.02 0.04 0.08 0.22 0.46 0.74 0.88 0.96 0.96 1.  ]

# %%
counts, bin_edges = np.histogram(iris_setosa['PetalLengthCm'], bins=10, 
                                 density = True)

print(counts)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
plt.gca().legend(('Pdf','Cdf'))
plt.title('PDF and CDF For iris_setosa')
plt.xlabel("Petal length")
plt.ylabel("Percentage")
plt.show();
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
counts, bin_edges = np.histogram(iris_setosa['PetalLengthCm'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(iris_setosa['PetalLengthCm'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf);
plt.gca().legend(('Pdf','Cdf','bin edges'))
plt.title('PDF and CDF For iris_setosa')
plt.xlabel("Petal length")
plt.ylabel("Percentage")
plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %% [markdown]
# ## PDF and CDF For all species

# %%
counts, bin_edges = np.histogram(iris_setosa['PetalLengthCm'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


# virginica
counts, bin_edges = np.histogram(iris_virginica['PetalLengthCm'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


#versicolor
counts, bin_edges = np.histogram(iris_versicolor['PetalLengthCm'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF For iris_versicolor')
plt.xlabel("Petal length")
plt.ylabel("Percentage")

plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %% [markdown]
# ## Mean, Variance, Std-deviation

# %%
#Mean, Variance, Std-deviation,  
print("Means:")
print(np.mean(iris_setosa["PetalLengthCm"]))
#Mean with an outlier.
print(np.mean(np.append(iris_setosa["PetalLengthCm"],50)));
print(np.mean(iris_virginica["PetalLengthCm"]))
print(np.mean(iris_versicolor["PetalLengthCm"]))

print("\nStd-dev:");
print(np.std(iris_setosa["PetalLengthCm"]))
print(np.std(iris_virginica["PetalLengthCm"]))
print(np.std(iris_versicolor["PetalLengthCm"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.5520000000000005
# 4.26
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %% [markdown]
# ## Median, Quantiles, Percentiles, IQR.

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(iris_setosa["PetalLengthCm"]))
#Median with an outlier
print(np.median(np.append(iris_setosa["PetalLengthCm"],50)));
print(np.median(iris_virginica["PetalLengthCm"]))
print(np.median(iris_versicolor["PetalLengthCm"]))


print("\nQuantiles:")
print(np.percentile(iris_setosa["PetalLengthCm"],np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["PetalLengthCm"],np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["PetalLengthCm"], np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(iris_setosa["PetalLengthCm"],90))
print(np.percentile(iris_virginica["PetalLengthCm"],90))
print(np.percentile(iris_versicolor["PetalLengthCm"], 90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["PetalLengthCm"]))
print(robust.mad(iris_virginica["PetalLengthCm"]))
print(robust.mad(iris_versicolor["PetalLengthCm"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.31
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='Species',y='PetalLengthCm', data=iris)
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x="Species", y="PetalLengthCm", data=iris, size=8)
plt.show()

# %% [markdown]
# ## Multivariate probability density, contour plot.

# %%
sns.jointplot(x="PetalLengthCm", y="PetalWidthCm", data=iris_setosa, kind="kde");
plt.show();
